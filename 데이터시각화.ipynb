# %%
import matplotlib.pyplot as pit
x_data = [2,3,4,5]
y_data = [1,3,5,7]

pit.plot(x_data,y_data, label = 'data')
pit.ylim(0,8)
pit.title('Graph Title')
pit.xlabel('x_name')
pit.ylabel('y_name')
pit.legend()
pit.show()
